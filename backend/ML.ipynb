# %% [markdown]
# # 1. Load Dataset

# %%
import pandas as pd

# laod empt dataframe
df = pd.DataFrame()

try:
    # Read dataset saved in directory
    df = pd.read_csv("OttawaON.csv", on_bad_lines='skip')
except FileNotFoundError:
    print("No dataset with that name!")

df.head(5)
# Out:
#          Id MlsNumber                                      PublicRemarks  \
# 0  26536455   1378295  Welcome to 66 Cobourg Street, located in the r...
# 1  26537184   1378320  Welcome to 70 Cobourg Street, located in the r...
# 2  26457670  13656864                   See listing broker(s) (40114534)
# 3  26471997   1375982  Bright and spacious Basement unit, 1 bedroom, ...
# 4  26465236   1375620  LOOKING FOR GREAT TENANTS AS OF MAY 1.  Rent t...
#
#                                           Individual PostalCode  \
# 0  [{'IndividualID': 2057519, 'Name': 'Kevin Cosg...     K1N8G8
# 1  [{'IndividualID': 2057519, 'Name': 'Kevin Cosg...     K1N8G8
# 2  [{'IndividualID': 1957812, 'Name': 'Epaphrodit...     J8P6P9
# 3  [{'IndividualID': 1966317, 'Name': 'Carlos Zar...     K2B5R6
# 4  [{'IndividualID': 1594252, 'Name': 'Johnny Hun...     K1K1W9
#
#    HistoricalDataIsCleared ProvinceName  \
# 0                    False      Ontario
# 1                    False      Ontario
# 2                    False       Quebec
# 3                    False      Ontario
# 4                    False      Ontario
#
#                                   RelativeDetailsURL  StatusId  \
# 0  /real-estate/26536455/66-cobourg-street-ottawa...         1
# 1  /real-estate/26537184/70-cobourg-street-ottawa...         1
# 2  /real-estate/26457670/94-rue-berthiaume-1-gati...         1
# 3  /real-estate/26471997/846b-alpine-avenue-unit1...         1
# 4  /real-estate/26465236/340-queen-mary-street-un...         1
#
#        PhotoChangeDateUTC  ...  AlternateURL.VideoLink HasNewImageUpdate  \
# 0   2024-02-21 8:11:48 PM  ...                     NaN               NaN
# 1  2024-02-21 10:11:24 PM  ...                     NaN               NaN
# 2   2024-01-29 8:10:31 PM  ...                     NaN               NaN
# 3   2024-02-04 8:41:27 PM  ...                     NaN               NaN
# 4   2024-01-31 7:11:49 PM  ...                     NaN               NaN
#
#   AlternateURL.PhotoLink OpenHouseInsertDateUTC  ListingTimeZone  \
# 0                    NaN                    NaN              NaN
# 1                    NaN                    NaN              NaN
# 2                    NaN                    NaN              NaN
# 3                    NaN                    NaN              NaN
# 4                    NaN                    NaN              NaN
#
#   ListingBoundary ListingGMT  Building.SizeExterior  Property.Price  \
# 0             NaN        NaN                    NaN             NaN
# 1             NaN        NaN                    NaN             NaN
# 2             NaN        NaN                    NaN             NaN
# 3             NaN        NaN                    NaN             NaN
# 4             NaN        NaN                    NaN             NaN
#
#   Property.PriceUnformattedValue
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## 2.1 Contact

# %%
df.describe()
# Out:
#                  Id  StatusId  Distance  InsertedDateUTC  UploadedBy  \
# count  9.900000e+01      99.0       0.0     9.900000e+01   99.000000
# mean   2.649079e+07       1.0       NaN     6.384277e+17   81.909091
# std    9.142464e+04       0.0       NaN     2.715233e+13   19.649527
# min    2.606314e+07       1.0       NaN     6.383040e+17    5.000000
# 25%    2.642782e+07       1.0       NaN     6.384121e+17   76.000000
# 50%    2.652974e+07       1.0       NaN     6.384404e+17   76.000000
# 75%    2.655747e+07       1.0       NaN     6.384467e+17   79.000000
# max    2.658404e+07       1.0       NaN     6.384526e+17  109.000000
#
#        Building.BathroomTotal  Building.StoriesTotal  \
# count               99.000000              85.000000
# mean                 1.323232               2.200000
# std                  0.682556               2.856905
# min                  1.000000               1.000000
# 25%                  1.000000               1.000000
# 50%                  1.000000               1.000000
# 75%                  1.000000               2.000000
# max                  3.000000              16.000000
#
#        Property.Address.Longitude  Property.Address.Latitude  \
# count                   99.000000                  99.000000
# mean                   -75.700938                  45.396001
# std                      0.147479                   0.084264
# min                    -76.183032                  45.089831
# 25%                    -75.747025                  45.386064
# 50%                    -75.695508                  45.419689
# 75%                    -75.657409                  45.438316
# max                    -75.252593                  45.521526
#
#        Property.ParkingSpaceTotal  Property.TypeId  \
# count                   92.000000             99.0
# mean                     1.010870            300.0
# std                      1.124107              0.0
# min                      0.000000            300.0
# 25%                      0.000000            300.0
# 50%                      1.000000            300.0
# 75%                      1.000000            300.0
# max                      6.000000            300.0
#
#        Property.LeaseRentUnformattedValue  Property.PriceUnformattedValue
# count                           99.000000                             1.0
# mean                          1890.444444                        349900.0
# std                            257.962710                             NaN
# min                           1200.000000                        349900.0
# 25%                           1750.000000                        349900.0
# 50%                           1870.000000                        349900.0
# 75%                           2075.000000                        349900.0
# max                           2300.000000                        349900.0

# %% [markdown]
# ## 2.2 Uncessessary/NULL Contact

# %%
# drop uncessessary/empty features
r_df = df.drop(['Id',
                'MlsNumber',
                'PublicRemarks',
                'Individual',
                'PostalCode',
                'TimeOnRealtor',
                'HistoricalDataIsCleared',
                'RelativeDetailsURL',
                'StatusId',
                'PhotoChangeDateUTC',
                'Distance',
                'RelativeURLEn',
                'RelativeURLFr',
                'Media',
                'Tags',
                'UploadedBy',
                'Property.Address.AddressText',
                'Property.Address.PermitShowAddress',
                'Property.Photo',
                'Property.Parking',
                'Land.SizeTotal',
                'Land.SizeFrontage',
                'Property.FarmType',
                'AlternateURL.DetailsLink',
                'Property.TypeId',
                'Property.OwnershipType',
                'Property.OwnershipTypeGroupIds',
                'Property.AmmenitiesNearBy',
                'Building.Ammenities',
                'Property.Type', # maybe
                'Property.ZoningType',
                'Land.AccessType',
                'Land.LandscapeFeatures',
                'Building.SizeInterior',
                'PriceChangeDateUTC',
                'Property.ParkingType',
                'Building.BathroomTotal',
                'HasNewImageUpdate',
                'Building.SizeExterior',
                'Property.Price',
                'Property.PriceUnformattedValue',
                'AlternateURL.PhotoLink',
                'OpenHouseInsertDateUTC',
                'ListingTimeZone',
                'ListingBoundary',
                'ListingGMT',
                'Property.LeaseRent',
                'AlternateURL.VideoLink']
               , axis=1)

#drop rows without our LeaseRent target
r_df.dropna(subset=['Property.LeaseRentUnformattedValue'], inplace=True)

r_df.dtypes
# Out:
# ProvinceName                           object
# InsertedDateUTC                         int64
# Building.Bedrooms                      object
# Building.StoriesTotal                 float64
# Building.Type                          object
# Property.Address.Longitude            float64
# Property.Address.Latitude             float64
# Property.ParkingSpaceTotal            float64
# Property.LeaseRentUnformattedValue      int64
# dtype: object

# %% [markdown]
# ## 2.3 Column Contact Evaluation

# %%
# how many empty cells in total
r_df.isnull().sum().max()
# Out:
# 14

# %% [markdown]
# ### 2.3.2 Numerical Contact

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

# %% [markdown]
# Standardizing numerical features is a preprocessing step that involves transforming the values of the numerical features in your dataset so that they have a mean of 0 and a standard deviation of 1. This process is also known as z-score normalization or standardization.
#
# The standardization formula for a feature $ X $ is given by:
#
# $$
# X_{\text{standardized}} = \frac{{X - \text{mean}(X)}}{{\text{std}(X)}}
# $$
#
# Here:
# - $ X $ is an individual data point in the numerical feature.
# - $ mean(X) $ is the mean (average) value of the feature across all data points.
# - $ std(X) $ is the standard deviation of the feature across all data points. In other words, it provides a way to understand how much individual data points differ from the mean of the set they are apart of.
#
# Where:
#
# The formula for calculating the standard deviation (σ) is as follows:
#
# $$
# \sigma = \sqrt{\frac{\sum{(X_i - \bar{X})^2}}{N}}
# $$
#
# As:
# - $ \sigma $ is the standard deviation.
# - $ X_i $ is each individual data point.
# - $ \bar{X} $ is the mean of the data points.
# - $ N $ is the total number of data points.
# - $ \sum $ denotes the sum over all data points.

# %%
r_df.columns = [col.replace('.', '') for col in r_df.columns]
r_df
# Out:
#    ProvinceName     InsertedDateUTC BuildingBedrooms  BuildingStoriesTotal  \
# 0       Ontario  638441430910900000            1 + 0                   1.0
# 1       Ontario  638441502846930000            1 + 0                   1.0
# 2        Quebec  638421553184730000                2                   1.0
# 3       Ontario  638424294909070000            0 + 1                   1.0
# 4       Ontario  638423251098900000            0 + 2                   1.0
# ..          ...                 ...              ...                   ...
# 94      Ontario  638404217858130000                1                   NaN
# 95      Ontario  638442510802800000            0 + 2                   1.0
# 96      Ontario  638446687017300000            1 + 0                   1.0
# 97      Ontario  638439486847470000            1 + 0                   1.0
# 98      Ontario  638451942658730000            0 + 2                   1.0
#
#    BuildingType  PropertyAddressLongitude  PropertyAddressLatitude  \
# 0         House                -75.679828                45.434023
# 1         House                -75.679828                45.434023
# 2         House                -75.595954                45.500238
# 3         House                -75.788561                45.360867
# 4         House                -75.651295                45.425107
# ..          ...                       ...                      ...
# 94    Apartment                -75.688857                45.429451
# 95    Apartment                -75.753395                45.342181
# 96    Apartment                -75.745355                45.391618
# 97    Apartment                -75.700708                45.417341
# 98    Apartment                -75.665565                45.444070
#
#     PropertyParkingSpaceTotal  PropertyLeaseRentUnformattedValue
# 0                         0.0                               1700
# 1                         0.0                               1700
# 2                         2.0                               1750
# 3                         0.0                               1750
# 4                         1.0                               1800
# ..                        ...                                ...
# 94                        NaN                               1900
# 95                        2.0                               1900
# 96                        0.0                               1900
# 97                        0.0                               1900
# 98                        2.0                               1900
#
# [99 rows x 9 columns]

# %%
# Convert 'InsertedDateUTC' to datetime format

# 'InsertedDateUTC' is in ticks
ticks_per_second = 1e7  # 1 tick = 100 nanoseconds, 1 second = 1e7 ticks
epoch_ticks = 621355968000000000  # Ticks from 0001-01-01 to 1970-01-01

# Convert 'InsertedDateUTC' to datetime format
r_df['InsertedDateUTC'] = pd.to_datetime((df['InsertedDateUTC'] - epoch_ticks) / ticks_per_second, unit='s', utc=True, errors='coerce')

# Convert to Canada (Eastern Time)
r_df['InsertedDateUTC'] = r_df['InsertedDateUTC'].dt.tz_convert('America/Toronto')


r_df.head(5)
# Out:
#   ProvinceName                     InsertedDateUTC BuildingBedrooms  \
# 0      Ontario 2024-02-21 15:11:31.089999914-05:00            1 + 0
# 1      Ontario 2024-02-21 17:11:24.693000078-05:00            1 + 0
# 2       Quebec 2024-01-29 15:01:58.473000050-05:00                2
# 3      Ontario 2024-02-01 19:11:30.907000065-05:00            0 + 1
# 4      Ontario 2024-01-31 14:11:49.890000105-05:00            0 + 2
#
#    BuildingStoriesTotal BuildingType  PropertyAddressLongitude  \
# 0                   1.0        House                -75.679828
# 1                   1.0        House                -75.679828
# 2                   1.0        House                -75.595954
# 3                   1.0        House                -75.788561
# 4                   1.0        House                -75.651295
#
#    PropertyAddressLatitude  PropertyParkingSpaceTotal  \
# 0                45.434023                        0.0
# 1                45.434023                        0.0
# 2                45.500238                        2.0
# 3                45.360867                        0.0
# 4                45.425107                        1.0
#
#    PropertyLeaseRentUnformattedValue
# 0                               1700
# 1                               1700
# 2                               1750
# 3                               1750
# 4                               1800

# %%
# For BuildingStoriesTotal        

r_df['BuildingStoriesTotal'] = r_df['BuildingStoriesTotal'].where(pd.notna(r_df['BuildingStoriesTotal']), 1)
r_df['BuildingStoriesTotal']
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
#      ...
# 94    1.0
# 95    1.0
# 96    1.0
# 97    1.0
# 98    1.0
# Name: BuildingStoriesTotal, Length: 99, dtype: float64

# %%
r_df['PropertyLeaseRentUnformattedValue'].astype(int)
# Out:
# 0     1700
# 1     1700
# 2     1750
# 3     1750
# 4     1800
#       ...
# 94    1900
# 95    1900
# 96    1900
# 97    1900
# 98    1900
# Name: PropertyLeaseRentUnformattedValue, Length: 99, dtype: int32

# %%
# No need For Property.Address.Longitude & Property.Address.Latitude

# %%
# No need For Property.TypeId

# %%
# Number of bedrooms
r_df['BuildingBedrooms'] = df['Building.Bedrooms'].where(pd.notna(df['Building.Bedrooms']), 0)

r_df['BuildingBedrooms'] = r_df['BuildingBedrooms'].apply(lambda x: float(str(x).split(' + ')[0]) + float(str(x).split(' + ')[1]) if '+' in str(x) else float(x))

r_df['BuildingBedrooms']
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     1.0
# 4     2.0
#      ...
# 94    1.0
# 95    2.0
# 96    1.0
# 97    1.0
# 98    2.0
# Name: BuildingBedrooms, Length: 99, dtype: float64

# %%
# Number of stories

r_df['BuildingStoriesTotal'] = df['Building.StoriesTotal'].where(pd.notna(df['Building.StoriesTotal']), 1)
r_df['BuildingStoriesTotal']
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
#      ...
# 94    1.0
# 95    1.0
# 96    1.0
# 97    1.0
# 98    1.0
# Name: BuildingStoriesTotal, Length: 99, dtype: float64

# %% [markdown]
# ### 2.3.1 Categorical Contact

# %%
# For:
r_df.select_dtypes(include=['object']).columns
# Out:
# Index(['ProvinceName', 'BuildingType'], dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# One-Hot Encoding creates additional columns in the dataset, where each column represents a unique category from the original categorical variable. Each row is then represented by binary values indicating the presence or absence of a particular category.
#
# Here's a simple example to illustrate:

# %% [markdown]
# Column in orignal dataframe:
#
# | Color |
# |-------|
# | Red   |
# | Blue  |
# | Green |
# | Red   |
# | Green |
#
# After One-Hot Enconding
#
# | Color_Red | Color_Blue | Color_Green |
# |-----------|------------|-------------|
# | 1         | 0          | 0           |
# | 0         | 1          | 0           |
# | 0         | 0          | 1           |
# | 1         | 0          | 0           |
# | 0         | 0          | 1           |

# %%
# For Building.Type

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
r_df['BuildingType'] = le.fit_transform(r_df['BuildingType'])
r_df['BuildingType']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 94    0
# 95    0
# 96    0
# 97    0
# 98    0
# Name: BuildingType, Length: 99, dtype: int32

# %%
# For Building.Ammenities
r_df['hasLaundry'] = df['Building.Ammenities']
r_df['hasLaundry'] = le.fit_transform(r_df['hasLaundry'])
r_df['hasLaundry']
# No need
# Out:
# 0     4
# 1     4
# 2     7
# 3     2
# 4     2
#      ..
# 94    6
# 95    2
# 96    2
# 97    3
# 98    2
# Name: hasLaundry, Length: 99, dtype: int32

# %%
# For Property.ZoningType
df['Property.AmmenitiesNearBy'] = df['Property.AmmenitiesNearBy'].where(pd.notna(df['Property.AmmenitiesNearBy']), '')


r_df['PublicTransit'] = df['Property.AmmenitiesNearBy'].str.contains('Public Transit').astype(int)
r_df['RecreationNearby'] = df['Property.AmmenitiesNearBy'].str.contains('Recreation Nearby').astype(int)
r_df['Shopping'] = df['Property.AmmenitiesNearBy'].str.contains('Shopping').astype(int)
r_df['Highway'] = df['Property.AmmenitiesNearBy'].str.contains('Highway').astype(int)
r_df['Park'] = df['Property.AmmenitiesNearBy'].str.contains('Park').astype(int)
r_df['Schools'] = df['Property.AmmenitiesNearBy'].str.contains('Schools').astype(int)
r_df['CEGEP'] = df['Property.AmmenitiesNearBy'].str.contains('CEGEP').astype(int)
r_df['Hospital'] = df['Property.AmmenitiesNearBy'].str.contains('Hospital').astype(int)
r_df['University'] = df['Property.AmmenitiesNearBy'].str.contains('University').astype(int)

# %%
r_df.columns
# Out:
# Index(['ProvinceName', 'InsertedDateUTC', 'BuildingBedrooms',
#        'BuildingStoriesTotal', 'BuildingType', 'PropertyAddressLongitude',
#        'PropertyAddressLatitude', 'PropertyParkingSpaceTotal',
#        'PropertyLeaseRentUnformattedValue', 'hasLaundry', 'PublicTransit',
#        'RecreationNearby', 'Shopping', 'Highway', 'Park', 'Schools', 'CEGEP',
#        'Hospital', 'University'],
#       dtype='object')

# %%
r_df.head(1)
# Out:
#   ProvinceName                     InsertedDateUTC  BuildingBedrooms  \
# 0      Ontario 2024-02-21 15:11:31.089999914-05:00               1.0
#
#    BuildingStoriesTotal  BuildingType  PropertyAddressLongitude  \
# 0                   1.0             1                -75.679828
#
#    PropertyAddressLatitude  PropertyParkingSpaceTotal  \
# 0                45.434023                        0.0
#
#    PropertyLeaseRentUnformattedValue  hasLaundry  PublicTransit  \
# 0                               1700           4              1
#
#    RecreationNearby  Shopping  Highway  Park  Schools  CEGEP  Hospital  \
# 0                 1         1        0     0        0      0         0
#
#    University
# 0           0

# %%
r_df['PropertyParkingType'] = df['Property.ParkingType'].where(pd.notna(df['Property.ParkingType']),0)
r_df['PropertyParkingType'] = pd.notna(df['Property.ParkingType'])
r_df['PropertyParkingType'] = r_df['PropertyParkingType'].astype(int)
r_df['PropertyParkingType']
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 94    1
# 95    1
# 96    0
# 97    0
# 98    1
# Name: PropertyParkingType, Length: 99, dtype: int32

# %%
r_df['ProvinceName'] = le.fit_transform(r_df['ProvinceName'])
r_df['ProvinceName']
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
#      ..
# 94    0
# 95    0
# 96    0
# 97    0
# 98    0
# Name: ProvinceName, Length: 99, dtype: int32

# %% [markdown]
# # Evaluation

# %%
from sklearn.compose import ColumnTransformer

# Bundle preprocessing for categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, r_df['ProvinceName'])
    ])

# %%
r_df['ProvinceName']
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
#      ..
# 94    0
# 95    0
# 96    0
# 97    0
# 98    0
# Name: ProvinceName, Length: 99, dtype: int32

# %% [markdown]
# # Feature Engineering

# %%
r_df['Year'] = r_df['InsertedDateUTC'].dt.year
r_df['Month'] = r_df['InsertedDateUTC'].dt.month
r_df['Day'] = r_df['InsertedDateUTC'].dt.day
r_df.drop('InsertedDateUTC', axis = 1, inplace=True)
r_df.dtypes
# Out:
# ProvinceName                           int32
# BuildingBedrooms                     float64
# BuildingStoriesTotal                 float64
# BuildingType                           int32
# PropertyAddressLongitude             float64
# PropertyAddressLatitude              float64
# PropertyParkingSpaceTotal            float64
# PropertyLeaseRentUnformattedValue      int64
# hasLaundry                             int32
# PublicTransit                          int32
# RecreationNearby                       int32
# Shopping                               int32
# Highway                                int32
# Park                                   int32
# Schools                                int32
# CEGEP                                  int32
# Hospital                               int32
# University                             int32
# PropertyParkingType                    int32
# Year                                   int32
# Month                                  int32
# Day                                    int32
# dtype: object

# %%
# transform into binary column
# r_df.rename(columns={'PropertyParkingSpaceTotal':'hasParkingSpace'}, inplace=True)

# Property.ParkingSpaceTotal != NaN => True : 1
# r_df['hasParkingSpace'] = df['Property.ParkingSpaceTotal'].where(pd.isna(df['Property.ParkingSpaceTotal']),1)

import numpy as np

r_df['PropertyParkingSpaceTotal'] = df['Property.ParkingSpaceTotal']

# Define conditions and corresponding values
conditions = [
    # # Small Pakring = 1 -->  0 < PropertyParkingSpaceTotal <= 5
    (r_df['PropertyParkingSpaceTotal'] > 0) & (r_df['PropertyParkingSpaceTotal'] <= 5),
    
    # Medium Parking = 2 --> 5 < PropertyParkingSpaceTotal <= 10
    (r_df['PropertyParkingSpaceTotal'] > 5) & (r_df['PropertyParkingSpaceTotal'] <= 10),

    # Large Parking = 3 --> PropertyParkingSpaceTotal > 10
    r_df['PropertyParkingSpaceTotal'] > 10
]

values = [1, 2, 3]

r_df['ParkingSizeType'] = np.select(conditions, values, default=0)

print(r_df[['PropertyParkingSpaceTotal','ParkingSizeType']].tail(10))

r_df.drop(['PropertyParkingSpaceTotal'], axis=1, inplace=True)
# Out:
#     PropertyParkingSpaceTotal  ParkingSizeType
# 89                        0.0                0
# 90                        NaN                0
# 91                        1.0                1
# 92                        0.0                0
# 93                        1.0                1
# 94                        NaN                0
# 95                        2.0                1
# 96                        0.0                0
# 97                        0.0                0
# 98                        2.0                1

# %%
r_df.isnull().sum().max()
# PropertyLeaseRentUnformattedValue
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axes = plt.subplots(ncols=4, nrows=2, figsize=(20,10))
colors = ["#0101DF", "#DF0101"]
sns.boxplot(x="BuildingBedrooms", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][0])
axes[0][0].set_title('BuildingBedrooms vs Rent')

sns.boxplot(x="hasLaundry", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][1])
axes[0][1].set_title('hasLaundry vs PropertyLeaseRentUnformattedValue')
# Out:
# C:\Users\moumi\AppData\Local\Temp\ipykernel_27692\3384201096.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="BuildingBedrooms", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][0])
# C:\Users\moumi\AppData\Local\Temp\ipykernel_27692\3384201096.py:6: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x="BuildingBedrooms", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][0])
# C:\Users\moumi\AppData\Local\Temp\ipykernel_27692\3384201096.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="hasLaundry", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][1])
# C:\Users\moumi\AppData\Local\Temp\ipykernel_27692\3384201096.py:9: UserWarning:
# The palette list has fewer values (2) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x="hasLaundry", y="PropertyLeaseRentUnformattedValue", data=r_df, palette=colors, ax=axes[0][1])
# Text(0.5, 1.0, 'hasLaundry vs PropertyLeaseRentUnformattedValue')

# %%
## Heatmap

# Calculate the correlation matrix
corr_matrix = r_df.select_dtypes('number').corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Create a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

plt.show()
# Show the plot

# %%
# Step 4: Contact Splitting
from sklearn.model_selection import train_test_split

features = r_df.drop('PropertyLeaseRentUnformattedValue', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, r_df['PropertyLeaseRentUnformattedValue'], test_size=0.2, random_state=42)

# %%
test_set = pd.DataFrame(X_test, columns=features.columns)
test_set['target'] = y_test

# Save the test set to a CSV file
test_set.to_csv('test_set.csv', index=False)

# %%
r_df.columns
# Out:
# Index(['ProvinceName', 'BuildingBedrooms', 'BuildingStoriesTotal',
#        'BuildingType', 'PropertyAddressLongitude', 'PropertyAddressLatitude',
#        'PropertyLeaseRentUnformattedValue', 'hasLaundry', 'PublicTransit',
#        'RecreationNearby', 'Shopping', 'Highway', 'Park', 'Schools', 'CEGEP',
#        'Hospital', 'University', 'PropertyParkingType', 'Year', 'Month', 'Day',
#        'ParkingSizeType'],
#       dtype='object')

# %%
r_df.dtypes
# Out:
# ProvinceName                           int32
# BuildingBedrooms                     float64
# BuildingStoriesTotal                 float64
# BuildingType                           int32
# PropertyAddressLongitude             float64
# PropertyAddressLatitude              float64
# PropertyLeaseRentUnformattedValue      int64
# hasLaundry                             int32
# PublicTransit                          int32
# RecreationNearby                       int32
# Shopping                               int32
# Highway                                int32
# Park                                   int32
# Schools                                int32
# CEGEP                                  int32
# Hospital                               int32
# University                             int32
# PropertyParkingType                    int32
# Year                                   int32
# Month                                  int32
# Day                                    int32
# ParkingSizeType                        int32
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 5: Model Training
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Step 6: Model Evaluation
y_pred = model.predict(X_test)

# Evaluate using different metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 74.37949999999998
# Mean Squared Error: 12640.17402499999
# R-squared: 0.8123230141488906

# %%
# serializing model
import pickle

# Save the model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
# Step 5: Model Training
model = sklearn.tree.DecisionTreeRegressor(max_depth=3)
model.fit(X_train, y_train)

# Step 6: Model Evaluation
y_pred = model.predict(X_test)

# Evaluate using different metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 96.91586538461539
# Mean Squared Error: 17842.106305987014
# R-squared: 0.7350865006984968

# %%
import xgboost as xgb

# Create XGBoost regressor
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# Fit the regressor to the training set
xg_reg.fit(X_train, y_train)

# Predictions
y_pred = xg_reg.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 134.35421752929688
# Mean Squared Error: 29045.36092783734
# R-squared: 0.5687444032722406

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create SVM regressor
svm_reg = SVC(kernel='linear', C=1.0)

# Fit the regressor to the training set
svm_reg.fit(X_train_scaled, y_train)

# Predictions
y_pred = svm_reg.predict(X_test_scaled)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 95.0
# Mean Squared Error: 30417.5
# R-squared: 0.5483713510719546

# %%
# from sklearn.cluster import KMeans
# from sklearn.preprocessing import StandardScaler

# # Assuming 'results_df' is your DataFrame with numerical features
# # Select relevant numerical features for clustering
# numerical_features = r_df.select_dtypes(include=['float64', 'int64'])

# # Standardize the features
# scaler = StandardScaler()
# numerical_features_scaled = scaler.fit_transform(numerical_features)

# # Choose the number of clusters (k)
# k = 3  # You can adjust this based on your requirements

# # Apply K-Means algorithm
# kmeans = KMeans(n_clusters=k, random_state=42)
# r_df['Cluster'] = kmeans.fit_predict(numerical_features_scaled)
# r_df['Cluster']

# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'property_data' with a column 'PropertyLeaseRentUnformattedValue'
# Example DataFrame creation (replace it with your actual DataFrame):
data = {
    'PropertyLeaseRentUnformattedValue': [1200, 1500, 1800, 2000, 2200, 2500, 2800, 3000, 3200, 3500]
}

property_data = pd.DataFrame(data)


# Assuming property_data is your DataFrame
plt.hist(property_data['PropertyLeaseRentUnformattedValue'], bins=10, edgecolor='black')
plt.title('Distribution of Rental Prices')
plt.xlabel('Rental Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# <div id='930cf748-e48a-4e52-820c-2b33b7bea8fa'></div>
